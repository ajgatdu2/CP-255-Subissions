# %% [markdown]
# ## Data collected so far

# %%
#Install proper packages

import networkx as nx
import osmnx as ox
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

ox.config(use_cache=True, log_console=True)
ox.__version__
# Out:
# '0.11.4'

# %%
#Extract walking network for Manila

G = ox.graph_from_place('Manila, Philippines', network_type='walk',)
fig, ax = ox.plot_graph(G, node_size = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e221d9629488> in <module>
#       1 #Extract walking network for Manila
#       2
# ----> 3 G = ox.graph_from_place('Manila, Philippines', network_type='walk',)
#       4 fig, ax = ox.plot_graph(G, node_size = 0)
#
# ~/.conda/envs/maps/lib/python3.7/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure, custom_filter)
#    1448                            max_query_area_size=max_query_area_size,
#    1449                            clean_periphery=clean_periphery, infrastructure=infrastructure,
# -> 1450                            custom_filter=custom_filter)
#    1451
#    1452     log('graph_from_place() returning graph with {:,} nodes and {:,} edges'.format(len(list(G.nodes())), len(list(G.edges()))))
#
# ~/.conda/envs/maps/lib/python3.7/site-packages/osmnx/core.py in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure, custom_filter)
#    1323                                           infrastructure=infrastructure, custom_filter=custom_filter)
#    1324         G_buffered = create_graph(response_jsons, name=name, retain_all=True,
# -> 1325                                   bidirectional=network_type in settings.bidirectional_network_types)
#    1326         G_buffered = truncate_graph_polygon(G_buffered, polygon_buffered, retain_all=True, truncate_by_edge=truncate_by_edge)
#    1327
#
# ~/.conda/envs/maps/lib/python3.7/site-packages/osmnx/core.py in create_graph(response_jsons, name, retain_all, bidirectional)
#     938     # use as weight
#     939     if len(G.edges) > 0:
# --> 940         G = add_edge_lengths(G)
#     941
#     942     return G
#
# ~/.conda/envs/maps/lib/python3.7/site-packages/osmnx/core.py in add_edge_lengths(G)
#     766     # first load all the edges' origin and destination coordinates as a
#     767     # dataframe indexed by u, v, key
# --> 768     coords = np.array([[u, v, k, G.nodes[u]['y'], G.nodes[u]['x'], G.nodes[v]['y'], G.nodes[v]['x']] for u, v, k in G.edges(keys=True)])
#     769     df_coords = pd.DataFrame(coords, columns=['u', 'v', 'k', 'u_y', 'u_x', 'v_y', 'v_x'])
#     770     df_coords[['u', 'v', 'k']] = df_coords[['u', 'v', 'k']].astype(np.int64)
#
# ~/.conda/envs/maps/lib/python3.7/site-packages/osmnx/core.py in <listcomp>(.0)
#     766     # first load all the edges' origin and destination coordinates as a
#     767     # dataframe indexed by u, v, key
# --> 768     coords = np.array([[u, v, k, G.nodes[u]['y'], G.nodes[u]['x'], G.nodes[v]['y'], G.nodes[v]['x']] for u, v, k in G.edges(keys=True)])
#     769     df_coords = pd.DataFrame(coords, columns=['u', 'v', 'k', 'u_y', 'u_x', 'v_y', 'v_x'])
#     770     df_coords[['u', 'v', 'k']] = df_coords[['u', 'v', 'k']].astype(np.int64)
#
# ~/.conda/envs/maps/lib/python3.7/site-packages/networkx/classes/graph.py in nodes(self)
#     755
#     756         """
# --> 757         nodes = NodeView(self)
#     758         # Lazy View creation: overload the (class) property on the instance
#     759         # Then future G.nodes use the existing View
#
# ~/.conda/envs/maps/lib/python3.7/site-packages/networkx/classes/reportviews.py in __init__(self, graph)
#     165         self._nodes = state['_nodes']
#     166
# --> 167     def __init__(self, graph):
#     168         self._nodes = graph._node
#     169
#
# KeyboardInterrupt:

# %%
# Convert to Shapefile 

ox.save_graph_shapefile(G, filename='mnl_walking')

# %%
#Calculate edge bearings and visualize their frequency to better understand grid 

G = ox.add_edge_bearings(G)
bearings = pd.Series([data['bearing'] for u, v, k, data in G.edges(keys=True, data=True)])
ax = bearings.hist(bins=30, zorder=2, alpha=0.8)
xlim = ax.set_xlim(0, 360)
ax.set_title('Manila street network edge bearings')
plt.show()

# %%
#Show edge bearings on a polar plot
#The grid is highly variable - a good sign for choice / connectivity

import numpy as np
n = 50
count, division = np.histogram(bearings, bins=[ang*360/n for ang in range(0,n+1)])
division = division[0:-1]
width =  2 * np.pi/n
ax = plt.subplot(111, projection='polar')
ax.set_theta_zero_location('N')
ax.set_theta_direction('clockwise')
bars = ax.bar(division * np.pi/180 - width * 0.5 , count, width=width, bottom=0.0)
ax.set_title('Manila street network edge bearings', y=1.1)
plt.show()

# %%
#What sized area does our network cover in square meters?
G_proj = ox.project_graph(G)
nodes_proj = ox.graph_to_gdfs(G_proj, edges=False)
graph_area_m = nodes_proj.unary_union.convex_hull.area
graph_area_m

# %%
#Here I'm showing other basic stats about the network
ox.basic_stats(G_proj, area=graph_area_m, clean_intersects=True, circuity_dist='euclidean')

# %%
#Here I have a generic polygon for the city, which I can export (I think) as a shapefile

city = ox.gdf_from_place('Manila, Philippines')
ox.save_gdf_shapefile(city)
city = ox.project_gdf(city)
fig, ax = ox.plot_shape(city, figsize=(5,5))

# %% [markdown]
# ## Data I still need:
# -Barangay polygons for Manila
#
# -Population density
#
# -Expected evacuation time from network
#
# -Lots of other data regarding different anchor institutions

# %% [markdown]
# ## Random data that may or may not be helpful

# %%
#GeoJSON of Rail Routes in Manila (there is one)
url = 'https://transit.land/api/v1/routes.geojson?operated_by=o-wdw4-philippinenationalrailways&per_page=false'

with open('routes.geojson', 'wb') as f:
    r = requests.get(url)
    f.write(r.content)

# %%
routes = gpd.read_file('routes.geojson')

# %%
routes.head() #Doesn't look too helpful...

# %%
#GeoJSON of rail stops in Manila (There are 34)
url = 'https://transit.land/api/v1/stops.geojson?served_by=o-wdw4-philippinenationalrailways&per_page=false'

with open('stops.geojson', 'wb') as f:
    r = requests.get(url)
    f.write(r.content)

# %%
stops = gpd.read_file('stops.geojson')

# %%
stops.head() #Again, doesn't seem super promising...

# %%
gdf = gpd.read_file('Metropolitan Manila')
print (gdf)

gdf.head()
# Out:
#       ID_0  ISO       NAME_0  ID_1               NAME_1  ID_2      NAME_2  \
# 0      177  PHL  Philippines    47  Metropolitan Manila   955      Manila
# 1      177  PHL  Philippines    47  Metropolitan Manila   955      Manila
# 2      177  PHL  Philippines    47  Metropolitan Manila   955      Manila
# 3      177  PHL  Philippines    47  Metropolitan Manila   955      Manila
# 4      177  PHL  Philippines    47  Metropolitan Manila   955      Manila
# ...    ...  ...          ...   ...                  ...   ...         ...
# 1686   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
# 1687   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
# 1688   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
# 1689   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
# 1690   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
#
#        ID_3         NAME_3 NL_NAME_3 VARNAME_3    TYPE_3 ENGTYPE_3  \
# 0     25137   Barangay 744      None      None  Barangay   Village
# 1     25138   Barangay 745      None      None  Barangay   Village
# 2     25139   Barangay 746      None      None  Barangay   Village
# 3     25140   Barangay 747      None      None  Barangay   Village
# 4     25141   Barangay 748      None      None  Barangay   Village
# ...     ...            ...       ...       ...       ...       ...
# 1686  25828         Rincon      None      None  Barangay   Village
# 1687  25829        Tagalag      None      None  Barangay   Village
# 1688  25830          Ugong      None      None  Barangay   Village
# 1689  25831  Viente Reales      None      None  Barangay   Village
# 1690  25832    Wawang Pulo      None      None  Barangay   Village
#
#                  PROVINCE               REGION  \
# 0     Metropolitan Manila  Metropolitan Manila
# 1     Metropolitan Manila  Metropolitan Manila
# 2     Metropolitan Manila  Metropolitan Manila
# 3     Metropolitan Manila  Metropolitan Manila
# 4     Metropolitan Manila  Metropolitan Manila
# ...                   ...                  ...
# 1686  Metropolitan Manila  Metropolitan Manila
# 1687  Metropolitan Manila  Metropolitan Manila
# 1688  Metropolitan Manila  Metropolitan Manila
# 1689  Metropolitan Manila  Metropolitan Manila
# 1690  Metropolitan Manila  Metropolitan Manila
#
#                                                geometry
# 0     POLYGON ((120.99477 14.57022, 120.99482 14.569...
# 1     POLYGON ((120.99721 14.56913, 120.99670 14.569...
# 2     POLYGON ((120.99826 14.56850, 120.99783 14.568...
# 3     POLYGON ((120.99947 14.57076, 120.99891 14.570...
# 4     POLYGON ((120.99860 14.57043, 120.99936 14.569...
# ...                                                 ...
# 1686  POLYGON ((120.95553 14.70852, 120.95574 14.708...
# 1687  POLYGON ((120.94740 14.72066, 120.94699 14.720...
# 1688  POLYGON ((121.02022 14.69872, 121.02026 14.698...
# 1689  POLYGON ((120.97366 14.71056, 120.97384 14.710...
# 1690  POLYGON ((120.93951 14.72433, 120.93874 14.723...
#
# [1691 rows x 16 columns]
#    ID_0  ISO       NAME_0  ID_1               NAME_1  ID_2  NAME_2   ID_3  \
# 0   177  PHL  Philippines    47  Metropolitan Manila   955  Manila  25137
# 1   177  PHL  Philippines    47  Metropolitan Manila   955  Manila  25138
# 2   177  PHL  Philippines    47  Metropolitan Manila   955  Manila  25139
# 3   177  PHL  Philippines    47  Metropolitan Manila   955  Manila  25140
# 4   177  PHL  Philippines    47  Metropolitan Manila   955  Manila  25141
#
#          NAME_3 NL_NAME_3 VARNAME_3    TYPE_3 ENGTYPE_3             PROVINCE  \
# 0  Barangay 744      None      None  Barangay   Village  Metropolitan Manila
# 1  Barangay 745      None      None  Barangay   Village  Metropolitan Manila
# 2  Barangay 746      None      None  Barangay   Village  Metropolitan Manila
# 3  Barangay 747      None      None  Barangay   Village  Metropolitan Manila
# 4  Barangay 748      None      None  Barangay   Village  Metropolitan Manila
#
#                 REGION                                           geometry
# 0  Metropolitan Manila  POLYGON ((120.99477 14.57022, 120.99482 14.569...
# 1  Metropolitan Manila  POLYGON ((120.99721 14.56913, 120.99670 14.569...
# 2  Metropolitan Manila  POLYGON ((120.99826 14.56850, 120.99783 14.568...
# 3  Metropolitan Manila  POLYGON ((120.99947 14.57076, 120.99891 14.570...
# 4  Metropolitan Manila  POLYGON ((120.99860 14.57043, 120.99936 14.569...

# %%
gdf.tail()
# Out:
#       ID_0  ISO       NAME_0  ID_1               NAME_1  ID_2      NAME_2  \
# 1686   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
# 1687   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
# 1688   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
# 1689   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
# 1690   177  PHL  Philippines    47  Metropolitan Manila   966  Valenzuela
#
#        ID_3         NAME_3 NL_NAME_3 VARNAME_3    TYPE_3 ENGTYPE_3  \
# 1686  25828         Rincon      None      None  Barangay   Village
# 1687  25829        Tagalag      None      None  Barangay   Village
# 1688  25830          Ugong      None      None  Barangay   Village
# 1689  25831  Viente Reales      None      None  Barangay   Village
# 1690  25832    Wawang Pulo      None      None  Barangay   Village
#
#                  PROVINCE               REGION  \
# 1686  Metropolitan Manila  Metropolitan Manila
# 1687  Metropolitan Manila  Metropolitan Manila
# 1688  Metropolitan Manila  Metropolitan Manila
# 1689  Metropolitan Manila  Metropolitan Manila
# 1690  Metropolitan Manila  Metropolitan Manila
#
#                                                geometry
# 1686  POLYGON ((120.95553 14.70852, 120.95574 14.708...
# 1687  POLYGON ((120.94740 14.72066, 120.94699 14.720...
# 1688  POLYGON ((121.02022 14.69872, 121.02026 14.698...
# 1689  POLYGON ((120.97366 14.71056, 120.97384 14.710...
# 1690  POLYGON ((120.93951 14.72433, 120.93874 14.723...

# %%
# %matplotlib inline
gdf.plot()

# %%
gdf.plot(column='NAME_2', cmap=None, legend=True, figsize=(20,20))

# %%
df = gdf.loc[gdf['NAME_2'] == 'Manila']
df.plot(figsize=(10,10))

# %%
gdf2 = gpd.read_file('edges')
gdf2.plot(color='red', figsize=(10,10))

# %%
gdf3 = gpd.read_file('nodes')
gdf3.plot(color='purple', figsize=(10,10))

# %%
f, ax = plt.subplots(1)
gdf2.plot(ax=ax, color = 'red', figsize=(10,10))
df.plot(ax=ax, figsize=(10,10))

plt.show()

# %%
conda install shapely

# %%
import shapely

# %%
cent = df.centroid
cent.plot(figsize=(10,10))

# %%
f, ax = plt.subplots(1)
gdf2.plot(ax=ax, color = 'red', figsize=(10,10))
cent.plot(ax=ax, figsize=(10,10))

plt.show()
